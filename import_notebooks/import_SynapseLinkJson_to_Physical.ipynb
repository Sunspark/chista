# %% [markdown]
# Imports a JSON file as found in the Synapse Link target datalake to the Phyiscal Structure and Physical Attribute hubs.
# Expected format:
# {
#
# \<some other keys\>
# , "entities": \[
#   {
#     "name": "entityName"
#     , "attributes": \[ \<list of entity attribute dictionaries\> \]
#     , \<some other keys\>
#   }
# \]
#
# <span style="color: var(--vscode-foreground);">}</span>

# %%
import sqlite3
import pandas as pd
import numpy as np
import os
import json
from datetime import datetime
import sys
sys.path.append('../')
from user_packages import hashing

# %%
# Set variables
target_model_name = 'contain.pig.tall' # from bv_Model
source_file_name = 'jsonformatter.txt'
source_file_path = ''

record_source = 'SynapseJSON'
SystemKeyPhrase = 'iPropertyCloud' # this should come from the System Hub, for linking structure to system
SERVER_NAME = 'ipctrain.crm11.dynamics.com' # the server you harvested from
DATABASE_NAME = 'ipctrain' # dynamics doesn't have a DB per se, so we're using the most specific part of the server URL, as that's what shows up in Synapse Link
SCHEMA_NAME = 'SynLink' # dynamics doesn't have a schema. What shows up in Synapse Link is a defined subset of dbo, so I'm calling it a different schema.

# %%
# Load JSON file
with open(os.path.join(source_file_path, source_file_name), 'r') as f:
  data = json.load(f)

# load db
conn = sqlite3.connect('../full_metadata.db')

# %%
# Extract entity information
entities = data['entities']
entity_info = [{'name': entity['name'], 'description': entity['description']} for entity in entities]

df_entities = pd.DataFrame(entity_info)

df_entities
# Out:
#                                         name  \
# 0                                    account
# 1                                appointment
# 2                             characteristic
# 3                                    contact
# 4                                      email
# 5                                   incident
# 6                                     letter
# 7                   msdyn_agentstatushistory
# 8                              msdyn_channel
# 9                       msdyn_ocliveworkitem
# 10        msdyn_ocliveworkitemcharacteristic
# 11                   msdyn_ocoutboundmessage
# 12                           msdyn_ocsession
# 13           msdyn_ocsessionparticipantevent
# 14                         msdyn_ocvoicemail
# 15                            msdyn_presence
# 16                        msdyn_sessionevent
# 17                              msdyn_slakpi
# 18                                msfp_alert
# 19                            msfp_alertrule
# 20                             msfp_question
# 21                     msfp_questionresponse
# 22                   msfp_satisfactionmetric
# 23                               msfp_survey
# 24                         msfp_surveyinvite
# 25                       msfp_surveyresponse
# 26                msfp_unsubscribedrecipient
# 27                                 phonecall
# 28                                     queue
# 29                                      role
# 30                            slakpiinstance
# 31                                systemuser
# 32                           systemuserroles
# 33                                      task
# 34                                      team
# 35                            teammembership
# 36                       tll_agreementaction
# 37                            tll_commitment
# 38                             tll_complaint
# 39                            tll_compliance
# 40          tll_compliancefireriskassessment
# 41  tll_compliancefireriskassessmentremedial
# 42                        tll_compliancetype
# 43                tll_complimentsandcomments
# 44                                  tll_flag
# 45                              tll_flagtype
# 46                              tll_occupant
# 47                         tll_portalmessage
# 48                              tll_property
# 49                     tll_propertyattribute
# 50                               tll_tenancy
# 51                     tllc_ohaccountbalance
# 52                                tllc_pcfra
# 53                        tllc_pcfraquestion
# 54                  tllc_pcfraquestionanswer
# 55                                 tllc_peep
# 56                         tllc_peepquestion
# 57                   tllc_peepquestionanswer
# 58                  tllc_portalnotifications
#
#                                  description
# 0                                    account
# 1                                appointment
# 2                             characteristic
# 3                                    contact
# 4                                      email
# 5                                   incident
# 6                                     letter
# 7                   msdyn_agentstatushistory
# 8                              msdyn_channel
# 9                       msdyn_ocliveworkitem
# 10        msdyn_ocliveworkitemcharacteristic
# 11                   msdyn_ocoutboundmessage
# 12                           msdyn_ocsession
# 13           msdyn_ocsessionparticipantevent
# 14                         msdyn_ocvoicemail
# 15                            msdyn_presence
# 16                        msdyn_sessionevent
# 17                              msdyn_slakpi
# 18                                msfp_alert
# 19                            msfp_alertrule
# 20                             msfp_question
# 21                     msfp_questionresponse
# 22                   msfp_satisfactionmetric
# 23                               msfp_survey
# 24                         msfp_surveyinvite
# 25                       msfp_surveyresponse
# 26                msfp_unsubscribedrecipient
# 27                                 phonecall
# 28                                     queue
# 29                                      role
# 30                            slakpiinstance
# 31                                systemuser
# 32                           systemuserroles
# 33                                      task
# 34                                      team
# 35                            teammembership
# 36                       tll_agreementaction
# 37                            tll_commitment
# 38                             tll_complaint
# 39                            tll_compliance
# 40          tll_compliancefireriskassessment
# 41  tll_compliancefireriskassessmentremedial
# 42                        tll_compliancetype
# 43                tll_complimentsandcomments
# 44                                  tll_flag
# 45                              tll_flagtype
# 46                              tll_occupant
# 47                         tll_portalmessage
# 48                              tll_property
# 49                     tll_propertyattribute
# 50                               tll_tenancy
# 51                     tllc_ohaccountbalance
# 52                                tllc_pcfra
# 53                        tllc_pcfraquestion
# 54                  tllc_pcfraquestionanswer
# 55                                 tllc_peep
# 56                         tllc_peepquestion
# 57                   tllc_peepquestionanswer
# 58                  tllc_portalnotifications

# %%
# Extract attribute information
attributes_info = []
for entity in entities:
  for attribute in entity['attributes']:
    attr_info = {
      'entity_name': entity['name']
      , 'name': attribute['name']
      , 'dataType': attribute['dataType']
      , 'maxLength': attribute['maxLength']
      , 'precision': None
      , 'scale': None
    }
    # Check for precision and scale in traits
    if 'cdm:traits' in attribute:
      for trait in attribute['cdm:traits']:
        if trait['traitReference'] == 'is.dataFormat.numeric.shaped':
          for arg in trait['arguments']:
            if arg['name'] == 'precision':
              attr_info['precision'] = arg['value']
            elif arg['name'] == 'scale':
              attr_info['scale'] = arg['value']
    attributes_info.append(attr_info)

df_attributes = pd.DataFrame(attributes_info)
df_attributes = df_attributes.replace({np.nan: None})

df_attributes
# Out:
#                    entity_name                       name  dataType  \
# 0                      account                         Id      guid
# 1                      account              SinkCreatedOn  dateTime
# 2                      account             SinkModifiedOn  dateTime
# 3                      account                  statecode     int64
# 4                      account                 statuscode     int64
# ...                        ...                        ...       ...
# 6995  tllc_portalnotifications  transactioncurrencyidname    string
# 6996  tllc_portalnotifications              traversedpath    string
# 6997  tllc_portalnotifications  utcconversiontimezonecode     int64
# 6998  tllc_portalnotifications              versionnumber     int64
# 6999  tllc_portalnotifications         tllc_createdbyuser   boolean
#
#       maxLength precision scale
# 0            -1      None  None
# 1            -1      None  None
# 2            -1      None  None
# 3            -1      None  None
# 4            -1      None  None
# ...         ...       ...   ...
# 6995        200      None  None
# 6996       2500      None  None
# 6997         -1      None  None
# 6998         -1      None  None
# 6999         -1      None  None
#
# [7000 rows x 6 columns]

# %%
# Physical Structure processing
# add extra columns
df = df_entities

# columns with variable data
df['RecordSource'] = record_source
df['LoadDate'] = datetime.now()
df['ModelKeyPhrase'] = target_model_name
df['SystemKeyPhrase'] = SystemKeyPhrase
df['SERVER_NAME'] = SERVER_NAME
df['DATABASE_NAME'] = DATABASE_NAME
df['SCHEMA_NAME'] = SCHEMA_NAME

# derive keyphrase columns
df['PhysicalStructureKeyPhrase'] = df.apply(
  lambda row: 
    row['SERVER_NAME']
    + '.' + row['DATABASE_NAME']
    + '.' + row['SCHEMA_NAME']
    + '.' + row['name'] # This corresponds to the Logical Name
  , axis=1
)
df['ModelPhysicalStructureKeyPhrase'] = df.apply(  lambda row: row['ModelKeyPhrase'] + ':' + row['PhysicalStructureKeyPhrase'], axis=1)
df['SystemPhysicalStructureKeyPhrase'] = df.apply(  lambda row: row['SystemKeyPhrase'] + ':' + row['PhysicalStructureKeyPhrase'], axis=1)

# hash the keyphrases
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'ModelHashKey'
  , columns = ['ModelKeyPhrase']
)
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'SystemHashKey'
  , columns = ['SystemKeyPhrase']
)
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'PhysicalStructureHashKey'
  , columns = ['PhysicalStructureKeyPhrase']
)
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'ModelPhysicalStructureHashKey'
  , columns = ['ModelPhysicalStructureKeyPhrase']
)
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'SystemPhysicalStructureHashKey'
  , columns = ['SystemPhysicalStructureKeyPhrase']
)


# hash the payload
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'HashDiff'
  , columns = [
      'name'
    , 'description'
    , 'SERVER_NAME'
    , 'DATABASE_NAME'
    , 'SCHEMA_NAME'
  ]
)

df
# Out:
#                                         name  \
# 0                                    account
# 1                                appointment
# 2                             characteristic
# 3                                    contact
# 4                                      email
# 5                                   incident
# 6                                     letter
# 7                   msdyn_agentstatushistory
# 8                              msdyn_channel
# 9                       msdyn_ocliveworkitem
# 10        msdyn_ocliveworkitemcharacteristic
# 11                   msdyn_ocoutboundmessage
# 12                           msdyn_ocsession
# 13           msdyn_ocsessionparticipantevent
# 14                         msdyn_ocvoicemail
# 15                            msdyn_presence
# 16                        msdyn_sessionevent
# 17                              msdyn_slakpi
# 18                                msfp_alert
# 19                            msfp_alertrule
# 20                             msfp_question
# 21                     msfp_questionresponse
# 22                   msfp_satisfactionmetric
# 23                               msfp_survey
# 24                         msfp_surveyinvite
# 25                       msfp_surveyresponse
# 26                msfp_unsubscribedrecipient
# 27                                 phonecall
# 28                                     queue
# 29                                      role
# 30                            slakpiinstance
# 31                                systemuser
# 32                           systemuserroles
# 33                                      task
# 34                                      team
# 35                            teammembership
# 36                       tll_agreementaction
# 37                            tll_commitment
# 38                             tll_complaint
# 39                            tll_compliance
# 40          tll_compliancefireriskassessment
# 41  tll_compliancefireriskassessmentremedial
# 42                        tll_compliancetype
# 43                tll_complimentsandcomments
# 44                                  tll_flag
# 45                              tll_flagtype
# 46                              tll_occupant
# 47                         tll_portalmessage
# 48                              tll_property
# 49                     tll_propertyattribute
# 50                               tll_tenancy
# 51                     tllc_ohaccountbalance
# 52                                tllc_pcfra
# 53                        tllc_pcfraquestion
# 54                  tllc_pcfraquestionanswer
# 55                                 tllc_peep
# 56                         tllc_peepquestion
# 57                   tllc_peepquestionanswer
# 58                  tllc_portalnotifications
#
#                                  description RecordSource  \
# 0                                    account  SynapseJSON
# 1                                appointment  SynapseJSON
# 2                             characteristic  SynapseJSON
# 3                                    contact  SynapseJSON
# 4                                      email  SynapseJSON
# 5                                   incident  SynapseJSON
# 6                                     letter  SynapseJSON
# 7                   msdyn_agentstatushistory  SynapseJSON
# 8                              msdyn_channel  SynapseJSON
# 9                       msdyn_ocliveworkitem  SynapseJSON
# 10        msdyn_ocliveworkitemcharacteristic  SynapseJSON
# 11                   msdyn_ocoutboundmessage  SynapseJSON
# 12                           msdyn_ocsession  SynapseJSON
# 13           msdyn_ocsessionparticipantevent  SynapseJSON
# 14                         msdyn_ocvoicemail  SynapseJSON
# 15                            msdyn_presence  SynapseJSON
# 16                        msdyn_sessionevent  SynapseJSON
# 17                              msdyn_slakpi  SynapseJSON
# 18                                msfp_alert  SynapseJSON
# 19                            msfp_alertrule  SynapseJSON
# 20                             msfp_question  SynapseJSON
# 21                     msfp_questionresponse  SynapseJSON
# 22                   msfp_satisfactionmetric  SynapseJSON
# 23                               msfp_survey  SynapseJSON
# 24                         msfp_surveyinvite  SynapseJSON
# 25                       msfp_surveyresponse  SynapseJSON
# 26                msfp_unsubscribedrecipient  SynapseJSON
# 27                                 phonecall  SynapseJSON
# 28                                     queue  SynapseJSON
# 29                                      role  SynapseJSON
# 30                            slakpiinstance  SynapseJSON
# 31                                systemuser  SynapseJSON
# 32                           systemuserroles  SynapseJSON
# 33                                      task  SynapseJSON
# 34                                      team  SynapseJSON
# 35                            teammembership  SynapseJSON
# 36                       tll_agreementaction  SynapseJSON
# 37                            tll_commitment  SynapseJSON
# 38                             tll_complaint  SynapseJSON
# 39                            tll_compliance  SynapseJSON
# 40          tll_compliancefireriskassessment  SynapseJSON
# 41  tll_compliancefireriskassessmentremedial  SynapseJSON
# 42                        tll_compliancetype  SynapseJSON
# 43                tll_complimentsandcomments  SynapseJSON
# 44                                  tll_flag  SynapseJSON
# 45                              tll_flagtype  SynapseJSON
# 46                              tll_occupant  SynapseJSON
# 47                         tll_portalmessage  SynapseJSON
# 48                              tll_property  SynapseJSON
# 49                     tll_propertyattribute  SynapseJSON
# 50                               tll_tenancy  SynapseJSON
# 51                     tllc_ohaccountbalance  SynapseJSON
# 52                                tllc_pcfra  SynapseJSON
# 53                        tllc_pcfraquestion  SynapseJSON
# 54                  tllc_pcfraquestionanswer  SynapseJSON
# 55                                 tllc_peep  SynapseJSON
# 56                         tllc_peepquestion  SynapseJSON
# 57                   tllc_peepquestionanswer  SynapseJSON
# 58                  tllc_portalnotifications  SynapseJSON
#
#                      LoadDate    ModelKeyPhrase SystemKeyPhrase  \
# 0  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 1  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 2  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 3  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 4  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 5  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 6  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 7  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 8  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 9  2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 10 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 11 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 12 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 13 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 14 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 15 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 16 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 17 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 18 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 19 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 20 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 21 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 22 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 23 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 24 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 25 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 26 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 27 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 28 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 29 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 30 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 31 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 32 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 33 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 34 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 35 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 36 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 37 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 38 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 39 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 40 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 41 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 42 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 43 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 44 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 45 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 46 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 47 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 48 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 49 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 50 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 51 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 52 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 53 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 54 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 55 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 56 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 57 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
# 58 2024-08-01 16:30:22.189653  contain.pig.tall  iPropertyCloud
#
#                     SERVER_NAME DATABASE_NAME SCHEMA_NAME  \
# 0   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 1   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 2   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 3   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 4   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 5   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 6   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 7   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 8   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 9   ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 10  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 11  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 12  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 13  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 14  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 15  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 16  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 17  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 18  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 19  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 20  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 21  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 22  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 23  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 24  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 25  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 26  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 27  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 28  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 29  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 30  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 31  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 32  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 33  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 34  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 35  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 36  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 37  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 38  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 39  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 40  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 41  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 42  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 43  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 44  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 45  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 46  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 47  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 48  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 49  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 50  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 51  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 52  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 53  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 54  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 55  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 56  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 57  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 58  ipctrain.crm11.dynamics.com      ipctrain     SynLink
#
#                            PhysicalStructureKeyPhrase  \
# 0   ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 1   ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 2   ipctrain.crm11.dynamics.com.ipctrain.SynLink.c...
# 3   ipctrain.crm11.dynamics.com.ipctrain.SynLink.c...
# 4   ipctrain.crm11.dynamics.com.ipctrain.SynLink.e...
# 5   ipctrain.crm11.dynamics.com.ipctrain.SynLink.i...
# 6   ipctrain.crm11.dynamics.com.ipctrain.SynLink.l...
# 7   ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 8   ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 9   ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 10  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 11  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 12  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 13  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 14  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 15  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 16  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 17  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 18  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 19  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 20  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 21  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 22  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 23  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 24  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 25  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 26  ipctrain.crm11.dynamics.com.ipctrain.SynLink.m...
# 27  ipctrain.crm11.dynamics.com.ipctrain.SynLink.p...
# 28  ipctrain.crm11.dynamics.com.ipctrain.SynLink.q...
# 29  ipctrain.crm11.dynamics.com.ipctrain.SynLink.role
# 30  ipctrain.crm11.dynamics.com.ipctrain.SynLink.s...
# 31  ipctrain.crm11.dynamics.com.ipctrain.SynLink.s...
# 32  ipctrain.crm11.dynamics.com.ipctrain.SynLink.s...
# 33  ipctrain.crm11.dynamics.com.ipctrain.SynLink.task
# 34  ipctrain.crm11.dynamics.com.ipctrain.SynLink.team
# 35  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 36  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 37  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 38  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 39  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 40  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 41  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 42  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 43  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 44  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 45  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 46  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 47  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 48  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 49  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 50  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 51  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 52  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 53  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 54  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 55  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 56  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 57  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 58  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
#
#                       ModelPhysicalStructureKeyPhrase  \
# 0   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 1   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 2   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 3   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 4   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 5   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 6   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 7   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 8   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 9   contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 10  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 11  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 12  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 13  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 14  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 15  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 16  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 17  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 18  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 19  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 20  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 21  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 22  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 23  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 24  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 25  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 26  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 27  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 28  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 29  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 30  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 31  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 32  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 33  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 34  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 35  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 36  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 37  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 38  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 39  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 40  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 41  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 42  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 43  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 44  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 45  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 46  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 47  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 48  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 49  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 50  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 51  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 52  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 53  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 54  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 55  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 56  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 57  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
# 58  contain.pig.tall:ipctrain.crm11.dynamics.com.i...
#
#                      SystemPhysicalStructureKeyPhrase  \
# 0   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 1   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 2   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 3   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 4   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 5   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 6   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 7   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 8   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 9   iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 10  iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 11  iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
# 12  iPropertyCloud:ipctrain.crm11.dynamics.com.ipc...
#
conn.commit()
df.to_sql('stg_Py_SynLinkJSONToPhysicalStructure', conn, if_exists='append', index=False)
# Out:
# 59

# %%
# Write to the Hub (PhysicalStructure)
sql_query = """
INSERT INTO rv_h_PhysicalStructure
(
    PhysicalStructureHashKey
  , LoadDate
  , RecordSource
  , PhysicalStructureKeyPhrase
)
SELECT DISTINCT
    PhysicalStructureHashKey
  , LoadDate
  , RecordSource
  , PhysicalStructureKeyPhrase
FROM
  stg_Py_SynLinkJSONToPhysicalStructure
WHERE
  PhysicalStructureHashKey NOT IN (SELECT PhysicalStructureHashKey FROM rv_h_PhysicalStructure)
""";
conn.execute(sql_query)
conn.commit()

# %%
# Write to the Satellite (PhysicalStructure_SynLinkJSON)
sql_query = """
INSERT INTO rv_s_PhysicalStructure_SynLinkJSON
(
    PhysicalStructureHashKey
  , LoadDate
  , RecordSource
  , HashDiff

  , "name"
  , "description"
  , "SERVER_NAME"
  , "DATABASE_NAME"
  , "SCHEMA_NAME"

)
SELECT DISTINCT
    stg.PhysicalStructureHashKey
  , stg.LoadDate
  , stg.RecordSource
  , stg.HashDiff
  
  , stg."name"
  , stg."description"
  , stg."SERVER_NAME"
  , stg."DATABASE_NAME"
  , stg."SCHEMA_NAME"

FROM
  stg_Py_SynLinkJSONToPhysicalStructure AS stg
  LEFT OUTER JOIN rv_s_PhysicalStructure_SynLinkJSON AS sat ON (
    stg.PhysicalStructureHashKey = sat.PhysicalStructureHashKey
    AND sat.LoadDate = (
      SELECT MAX(z.LoadDate)
      FROM rv_s_PhysicalStructure_SynLinkJSON AS z
      WHERE z.PhysicalStructureHashKey = sat.PhysicalStructureHashKey
    )
  )
WHERE
  (
    sat.HashDiff != stg.HashDiff
    OR sat.HashDiff IS NULL
  )
""";
conn.execute(sql_query)
conn.commit()

# %%
# Write to the Link (Model - PhysicalStructure)
sql_query = """
INSERT INTO rv_l_ModelPhysicalStructure
(
  ModelPhysicalStructureHashKey
  , LoadDate
  , RecordSource
  , ModelHashKey
  , PhysicalStructureHashKey
)
SELECT
  stg.ModelPhysicalStructureHashKey
  , stg.LoadDate
  , stg.RecordSource
  , stg.ModelHashKey
  , stg.PhysicalStructureHashKey
FROM
  stg_Py_SynLinkJSONToPhysicalStructure stg
WHERE
  stg.ModelPhysicalStructureHashKey IS NOT NULL
  AND ModelPhysicalStructureHashKey NOT IN (
    SELECT ModelPhysicalStructureHashKey
    FROM rv_l_ModelPhysicalStructure
  )
""";
conn.execute(sql_query)
conn.commit()

# %%
# Write to the Link (System - PhysicalStructure)
sql_query = """
INSERT INTO rv_l_SystemPhysicalStructure
(
  SystemPhysicalStructureHashKey
  , LoadDate
  , RecordSource
  , SystemHashKey
  , PhysicalStructureHashKey
)
SELECT
  stg.SystemPhysicalStructureHashKey
  , stg.LoadDate
  , stg.RecordSource
  , stg.SystemHashKey
  , stg.PhysicalStructureHashKey
FROM
  stg_Py_SynLinkJSONToPhysicalStructure stg
WHERE
  stg.SystemPhysicalStructureHashKey IS NOT NULL
  AND SystemPhysicalStructureHashKey NOT IN (
    SELECT SystemPhysicalStructureHashKey
    FROM rv_l_SystemPhysicalStructure
  )
""";
conn.execute(sql_query)
conn.commit()

# %%
# Processing the attributes
df = df_attributes

# add extra columns

# columns with variable data
df['RecordSource'] = record_source
df['LoadDate'] = datetime.now()
df['ModelKeyPhrase'] = target_model_name
df['SERVER_NAME'] = SERVER_NAME
df['DATABASE_NAME'] = DATABASE_NAME
df['SCHEMA_NAME'] = SCHEMA_NAME

# derive keyphrase columns
df['PhysicalStructureKeyPhrase'] = df.apply(
  lambda row: 
    row['SERVER_NAME']
    + '.' + row['DATABASE_NAME']
    + '.' + row['SCHEMA_NAME']
    + '.' + row['entity_name']
  , axis=1
)
df['PhysicalAttributeKeyPhrase'] = df.apply(
  lambda row: 
    row['SERVER_NAME']
    + '.' + row['DATABASE_NAME']
    + '.' + row['SCHEMA_NAME']
    + '.' + row['entity_name']
    + '.' + row['name']
  , axis=1
)
df['PhysicalStructurePhysicalAttributeKeyPhrase'] = df.apply(  lambda row: row['PhysicalStructureKeyPhrase'] + ':' + row['PhysicalAttributeKeyPhrase'], axis=1)

# hash the keyphrases
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'PhysicalStructureHashKey'
  , columns = ['PhysicalStructureKeyPhrase']
)
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'PhysicalAttributeHashKey'
  , columns = ['PhysicalAttributeKeyPhrase']
)
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'PhysicalStructurePhysicalAttributeHashKey'
  , columns = ['PhysicalStructurePhysicalAttributeKeyPhrase']
)

# hash the payload
df = hashing.add_md5_hash_column(
  df
  , md5_column_name = 'HashDiff'
  , columns = [
      'entity_name'
    , 'name'
    , 'dataType'
    , 'maxLength'
    , 'precision'
    , 'scale'
    , 'SERVER_NAME'
    , 'DATABASE_NAME'
    , 'SCHEMA_NAME'
  ]
)

df
# Out:
#                    entity_name                       name  dataType  \
# 0                      account                         Id      guid
# 1                      account              SinkCreatedOn  dateTime
# 2                      account             SinkModifiedOn  dateTime
# 3                      account                  statecode     int64
# 4                      account                 statuscode     int64
# ...                        ...                        ...       ...
# 6995  tllc_portalnotifications  transactioncurrencyidname    string
# 6996  tllc_portalnotifications              traversedpath    string
# 6997  tllc_portalnotifications  utcconversiontimezonecode     int64
# 6998  tllc_portalnotifications              versionnumber     int64
# 6999  tllc_portalnotifications         tllc_createdbyuser   boolean
#
#       maxLength precision scale RecordSource                   LoadDate  \
# 0            -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 1            -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 2            -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 3            -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 4            -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# ...         ...       ...   ...          ...                        ...
# 6995        200      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 6996       2500      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 6997         -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 6998         -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
# 6999         -1      None  None  SynapseJSON 2024-08-01 16:43:57.349110
#
#         ModelKeyPhrase                  SERVER_NAME DATABASE_NAME SCHEMA_NAME  \
# 0     contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 1     contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 2     contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 3     contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 4     contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# ...                ...                          ...           ...         ...
# 6995  contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 6996  contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 6997  contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 6998  contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
# 6999  contain.pig.tall  ipctrain.crm11.dynamics.com      ipctrain     SynLink
#
#                              PhysicalStructureKeyPhrase  \
# 0     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 1     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 2     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 3     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 4     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# ...                                                 ...
# 6995  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6996  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6997  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6998  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6999  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
#
#                              PhysicalAttributeKeyPhrase  \
# 0     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 1     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 2     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 3     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 4     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# ...                                                 ...
# 6995  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6996  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6997  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6998  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6999  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
#
#             PhysicalStructurePhysicalAttributeKeyPhrase  \
# 0     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 1     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 2     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 3     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# 4     ipctrain.crm11.dynamics.com.ipctrain.SynLink.a...
# ...                                                 ...
# 6995  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6996  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6997  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6998  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
# 6999  ipctrain.crm11.dynamics.com.ipctrain.SynLink.t...
#
#               PhysicalStructureHashKey          PhysicalAttributeHashKey  \
# 0     808cb41c48b6f9e04e11e53019506d85  438db05224ffc0295922301d2417105a
# 1     808cb41c48b6f9e04e11e53019506d85  c6c29f0044fcc1a789ac351791930f77
# 2     808cb41c48b6f9e04e11e53019506d85  3a9c08b035950bcc4ecbbb8814c54302
# 3     808cb41c48b6f9e04e11e53019506d85  fb308298cc4be0ba6d7f83807f910dd3
# 4     808cb41c48b6f9e04e11e53019506d85  daed55010cbeefb055d7d02369331614
# ...                                ...                               ...
# 6995  85f5860b362a718b1c3bf6562eaabc8b  966e391a82882ed5d62bf38964209d34
# 6996  85f5860b362a718b1c3bf6562eaabc8b  f45df3e9fbb00f6525ccdb98d46fada1
# 6997  85f5860b362a718b1c3bf6562eaabc8b  ffb7d96dd41c283d93c908285c76210e
# 6998  85f5860b362a718b1c3bf6562eaabc8b  54886b3eca3ca289e2ce70f0573fba11
# 6999  85f5860b362a718b1c3bf6562eaabc8b  3c17ee058b46caa3f5cc7a2d806d11ea
#
#      PhysicalStructurePhysicalAttributeHashKey  \
# 0             33ed9a4d481dcfe785fa90cc07679797
# 1             bda0b8f7e99d141510f226dba0e8f765
# 2             49824c43aaacf615f96353a9c2a5dd50
# 3             eb19134ec95e94d1390bd23f1bc909fe
# 4             51b575272bc05007019882be01f50ddc
# ...                                        ...
# 6995          d97171eed67714665cb782feec71a294
# 6996          4a9302ba35688563cd02e3fe1bee802e
# 6997          73f8b9f1afe047beaec3960432d822a3
# 6998          672382ef193ddf9501cfe5090ba44598
# 6999          1b820e2aa657e93ce8769ef6a7a4201f
#
#                               HashDiff
# 0     14d0ec86c3165e839b857d0b13042524
# 1     0119a1a5e574da831c1dbf4cb9971f0c
# 2     f23c50601eb01d4a31af0367a3c5a1b8
# 3     8f9099316c866893d2adafdc5e39bf4a
# 4     28c9033a45c2021f4ea14adfb12893c7
# ...                                ...
# 6995  cd949356a582ba8efabf4c40d2312a61
# 6996  d6a4b98caf9bbdef74b338574ac7fd15
# 6997  af8c919bba57e853fb45ebde17a5ba57
# 6998  bd5fd91cd33cb0e1eb72221e67625082
# 6999  acf2504d6df99273c98039a8a8a87383
#
# [7000 rows x 19 columns]

# %%
# Clear down and Write to staging
conn.execute("DELETE FROM stg_Py_SynLinkJSONToPhysicalAttribute")
conn.commit()
df.to_sql('stg_Py_SynLinkJSONToPhysicalAttribute', conn, if_exists='append', index=False)
# Out:
# 7000

# %%
# Write to the Hub (PhysicalAttribute)
sql_query = """
INSERT INTO rv_h_PhysicalAttribute
(
    PhysicalAttributeHashKey
  , LoadDate
  , RecordSource
  , PhysicalAttributeKeyPhrase
)
SELECT DISTINCT
    PhysicalAttributeHashKey
  , LoadDate
  , RecordSource
  , PhysicalAttributeKeyPhrase
FROM
  stg_Py_SynLinkJSONToPhysicalAttribute
WHERE
  PhysicalAttributeHashKey NOT IN (SELECT PhysicalAttributeHashKey FROM rv_h_PhysicalAttribute)
""";
conn.execute(sql_query)
conn.commit()

# %%
# Write to the Satellite (PhysicalAttribute_SynLinkJSON)
sql_query = """
INSERT INTO rv_s_PhysicalAttribute_SynLinkJSON
(
    PhysicalAttributeHashKey
  , LoadDate
  , RecordSource
  , HashDiff

  , "entity_name"
  , "name"
  , "dataType"
  , "maxLength"
  , "precision"
  , "scale"
  , "SERVER_NAME"
  , "DATABASE_NAME"
  , "SCHEMA_NAME"

)
SELECT DISTINCT
    stg.PhysicalAttributeHashKey
  , stg.LoadDate
  , stg.RecordSource
  , stg.HashDiff
  
  , stg."entity_name"
  , stg."name"
  , stg."dataType"
  , stg."maxLength"
  , stg."precision"
  , stg."scale"
  , stg."SERVER_NAME"
  , stg."DATABASE_NAME"
  , stg."SCHEMA_NAME"

FROM
  stg_Py_SynLinkJSONToPhysicalAttribute AS stg
  LEFT OUTER JOIN rv_s_PhysicalAttribute_SynLinkJSON AS sat ON (
    stg.PhysicalAttributeHashKey = sat.PhysicalAttributeHashKey
    AND sat.LoadDate = (
      SELECT MAX(z.LoadDate)
      FROM rv_s_PhysicalAttribute_SynLinkJSON AS z
      WHERE z.PhysicalAttributeHashKey = sat.PhysicalAttributeHashKey
    )
  )
WHERE
  (
    sat.HashDiff != stg.HashDiff
    OR sat.HashDiff IS NULL
  )
""";
conn.execute(sql_query)
conn.commit()

# %%
# Write to the Link (PhysicalStructure - PhysicalAttribute)
sql_query = """
INSERT INTO rv_l_PhysicalStructurePhysicalAttribute
(
  PhysicalStructurePhysicalAttributeHashKey
  , LoadDate
  , RecordSource
  , PhysicalStructureHashKey
  , PhysicalAttributeHashKey
)
SELECT
  stg.PhysicalStructurePhysicalAttributeHashKey
  , stg.LoadDate
  , stg.RecordSource
  , stg.PhysicalStructureHashKey
  , stg.PhysicalAttributeHashKey
FROM
  stg_Py_SynLinkJSONToPhysicalAttribute stg
WHERE
  stg.PhysicalStructurePhysicalAttributeHashKey IS NOT NULL
  AND PhysicalStructurePhysicalAttributeHashKey NOT IN (
    SELECT PhysicalStructurePhysicalAttributeHashKey
    FROM rv_l_PhysicalStructurePhysicalAttribute
  )
""";
conn.execute(sql_query)
conn.commit()
